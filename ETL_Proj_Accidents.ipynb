# %% [markdown]
# # Import dependencies

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests

# SQLAlchemy
from sqlalchemy import create_engine
from secret import username, password
import psycopg2

# %% [markdown]
# # Store CSV into DataFrame

# %%
accident_csv_file = "Resources/US_Accidents_June20.csv"
accident_data_df = pd.read_csv(accident_csv_file)
accident_data_df.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False          False        False          Night          Night
# 1           False          False        False          Night          Night
# 2           False           True        False          Night          Night
# 3           False          False        False          Night            Day
# 4           False           True        False            Day            Day
#
#   Nautical_Twilight Astronomical_Twilight
# 0             Night                 Night
# 1             Night                   Day
# 2               Day                   Day
# 3               Day                   Day
# 4               Day                   Day
#
# [5 rows x 49 columns]

# %%
state_csv_file = "Resources/state_csvData.csv"
state_df = pd.read_csv(state_csv_file)
state_df.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
# Rename columns to match accident df for future merging
state_df = state_df.drop(columns={"Abbrev"})
state_df = state_df.rename(columns={"State": "state_name",
                                   "Code": "State"})
state_df.head()
# Out:
#    state_name State
# 0     Alabama    AL
# 1      Alaska    AK
# 2     Arizona    AZ
# 3    Arkansas    AR
# 4  California    CA

# %% [markdown]
# # accident_df

# %%
# view data before transformation
# accident_data_df.nunique()

# %%
# accident_data_df.info()

# %% [markdown]
# # Create new accident df

# %%
new_accident_data_df = accident_data_df[['ID', 'Start_Time', 'City', 'County', 'State', 'Zipcode', 'Street', 'Timezone', 'Temperature(F)', 'Visibility(mi)', 'Weather_Condition']].copy()
new_accident_data_df.head()
# Out:
#     ID           Start_Time          City      County State     Zipcode  \
# 0  A-1  2016-02-08 05:46:00        Dayton  Montgomery    OH       45424
# 1  A-2  2016-02-08 06:07:59  Reynoldsburg    Franklin    OH  43068-3402
# 2  A-3  2016-02-08 06:49:27  Williamsburg    Clermont    OH       45176
# 3  A-4  2016-02-08 07:23:34        Dayton  Montgomery    OH       45417
# 4  A-5  2016-02-08 07:39:07        Dayton  Montgomery    OH       45459
#
#                       Street    Timezone  Temperature(F)  Visibility(mi)  \
# 0                     I-70 E  US/Eastern            36.9            10.0
# 1                   Brice Rd  US/Eastern            37.9            10.0
# 2             State Route 32  US/Eastern            36.0            10.0
# 3                     I-75 S  US/Eastern            35.1             9.0
# 4  Miamisburg Centerville Rd  US/Eastern            36.0             6.0
#
#   Weather_Condition
# 0        Light Rain
# 1        Light Rain
# 2          Overcast
# 3     Mostly Cloudy
# 4     Mostly Cloudy

# %% [markdown]
# # merge state and accident df

# %%
# Merge accident_df with state_df to obtain state_name for future merging with population df
clean_accident_data_df = pd.merge(new_accident_data_df, state_df, on= "State")
clean_accident_data_df.head()
# Out:
#     ID           Start_Time          City      County State     Zipcode  \
# 0  A-1  2016-02-08 05:46:00        Dayton  Montgomery    OH       45424
# 1  A-2  2016-02-08 06:07:59  Reynoldsburg    Franklin    OH  43068-3402
# 2  A-3  2016-02-08 06:49:27  Williamsburg    Clermont    OH       45176
# 3  A-4  2016-02-08 07:23:34        Dayton  Montgomery    OH       45417
# 4  A-5  2016-02-08 07:39:07        Dayton  Montgomery    OH       45459
#
#                       Street    Timezone  Temperature(F)  Visibility(mi)  \
# 0                     I-70 E  US/Eastern            36.9            10.0
# 1                   Brice Rd  US/Eastern            37.9            10.0
# 2             State Route 32  US/Eastern            36.0            10.0
# 3                     I-75 S  US/Eastern            35.1             9.0
# 4  Miamisburg Centerville Rd  US/Eastern            36.0             6.0
#
#   Weather_Condition state_name
# 0        Light Rain       Ohio
# 1        Light Rain       Ohio
# 2          Overcast       Ohio
# 3     Mostly Cloudy       Ohio
# 4     Mostly Cloudy       Ohio

# %%
# convert start_time from object to datetime 
clean_accident_data_df['Start_Time'] = pd.to_datetime(clean_accident_data_df['Start_Time'])
clean_accident_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3513617 entries, 0 to 3513616
# Data columns (total 12 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ID                 object
#  1   Start_Time         datetime64[ns]
#  2   City               object
#  3   County             object
#  4   State              object
#  5   Zipcode            object
#  6   Street             object
#  7   Timezone           object
#  8   Temperature(F)     float64
#  9   Visibility(mi)     float64
#  10  Weather_Condition  object
#  11  state_name         object
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 348.5+ MB

# %%
# clean_accident_data_df.nunique()

# %%
# Limit data from 2016-2020 to 2016 only
clean_accident_data_df = clean_accident_data_df[(clean_accident_data_df['Start_Time']>= "2016-01-01") & 
                                            (clean_accident_data_df['Start_Time']<= "2018-12-31")]
# clean_accident_data_df.nunique()

# %%
clean_accident_data_df.head()
# Out:
#     ID          Start_Time          City      County State     Zipcode  \
# 0  A-1 2016-02-08 05:46:00        Dayton  Montgomery    OH       45424
# 1  A-2 2016-02-08 06:07:59  Reynoldsburg    Franklin    OH  43068-3402
# 2  A-3 2016-02-08 06:49:27  Williamsburg    Clermont    OH       45176
# 3  A-4 2016-02-08 07:23:34        Dayton  Montgomery    OH       45417
# 4  A-5 2016-02-08 07:39:07        Dayton  Montgomery    OH       45459
#
#                       Street    Timezone  Temperature(F)  Visibility(mi)  \
# 0                     I-70 E  US/Eastern            36.9            10.0
# 1                   Brice Rd  US/Eastern            37.9            10.0
# 2             State Route 32  US/Eastern            36.0            10.0
# 3                     I-75 S  US/Eastern            35.1             9.0
# 4  Miamisburg Centerville Rd  US/Eastern            36.0             6.0
#
#   Weather_Condition state_name
# 0        Light Rain       Ohio
# 1        Light Rain       Ohio
# 2          Overcast       Ohio
# 3     Mostly Cloudy       Ohio
# 4     Mostly Cloudy       Ohio

# %% [markdown]
# # Check to see if all 2016 data is present

# %%
# Sort by datetime
clean_accident_data_df = clean_accident_data_df.sort_values('Start_Time')
clean_accident_data_df.head()
# Out:
#               ID          Start_Time          City      County State  \
# 45629  A-2478859 2016-02-08 00:37:08        Dublin    Franklin    OH
# 0            A-1 2016-02-08 05:46:00        Dayton  Montgomery    OH
# 45630  A-2478860 2016-02-08 05:56:20        Dayton  Montgomery    OH
# 1            A-2 2016-02-08 06:07:59  Reynoldsburg    Franklin    OH
# 45631  A-2478861 2016-02-08 06:15:39    Cincinnati    Hamilton    OH
#
#           Zipcode       Street    Timezone  Temperature(F)  Visibility(mi)  \
# 45629       43017  Outerbelt E  US/Eastern            42.1            10.0
# 0           45424       I-70 E  US/Eastern            36.9            10.0
# 45630       45424       I-70 E  US/Eastern            36.9            10.0
# 1      43068-3402     Brice Rd  US/Eastern            37.9            10.0
# 45631       45203       I-75 S  US/Eastern            36.0            10.0
#
#       Weather_Condition state_name
# 45629        Light Rain       Ohio
# 0            Light Rain       Ohio
# 45630        Light Rain       Ohio
# 1            Light Rain       Ohio
# 45631          Overcast       Ohio

# %%
# clean_accident_data_df.count()

# %%
# clean_accident_data_df.nunique()

# %% [markdown]
# # Test to see if correct data is included

# %%
# clean_accident_data_df['normalised_date'] = clean_accident_data_df['Start_Time'].dt.normalize()
# clean_accident_data_df.head()

# %% [markdown]
# # Reorganize df to look pretty

# %%
clean_accident_data_df = clean_accident_data_df[['ID', 'Start_Time', 'City', 'County', 'State', 'state_name', 'Zipcode', 'Street', 'Timezone', 'Temperature(F)', 'Visibility(mi)', 'Weather_Condition']]
clean_accident_data_df.head()
# Out:
#               ID          Start_Time          City      County State  \
# 45629  A-2478859 2016-02-08 00:37:08        Dublin    Franklin    OH
# 0            A-1 2016-02-08 05:46:00        Dayton  Montgomery    OH
# 45630  A-2478860 2016-02-08 05:56:20        Dayton  Montgomery    OH
# 1            A-2 2016-02-08 06:07:59  Reynoldsburg    Franklin    OH
# 45631  A-2478861 2016-02-08 06:15:39    Cincinnati    Hamilton    OH
#
#       state_name     Zipcode       Street    Timezone  Temperature(F)  \
# 45629       Ohio       43017  Outerbelt E  US/Eastern            42.1
# 0           Ohio       45424       I-70 E  US/Eastern            36.9
# 45630       Ohio       45424       I-70 E  US/Eastern            36.9
# 1           Ohio  43068-3402     Brice Rd  US/Eastern            37.9
# 45631       Ohio       45203       I-75 S  US/Eastern            36.0
#
#        Visibility(mi) Weather_Condition
# 45629            10.0        Light Rain
# 0                10.0        Light Rain
# 45630            10.0        Light Rain
# 1                10.0        Light Rain
# 45631            10.0          Overcast

# %%
clean_accident_data_df = clean_accident_data_df.rename(columns={"State": "state_abbrev",
                                                               "state_name":"State",
                                                               "Start_Time": "Date_Time"})

# %%
#import US state 2 letter abbreviation dictionary to create a state table 
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
state_series = pd.Series(us_state_abbrev)

# %%
state_df = state_series.to_frame()

# %%
state_df.reset_index(inplace=True)

# %%
state_df.rename(columns={"index":"state",0:"statecode"}, inplace=True)

# %%
# state1_df = pd.merge(state_df,state_pop1_df, on="state" )

# %% [markdown]
# ## Extract,Clean,Transform Accident data

# %%
clean_accident_data_df.head()
# Out:
#               ID           Date_Time          City      County state_abbrev  \
# 45629  A-2478859 2016-02-08 00:37:08        Dublin    Franklin           OH
# 0            A-1 2016-02-08 05:46:00        Dayton  Montgomery           OH
# 45630  A-2478860 2016-02-08 05:56:20        Dayton  Montgomery           OH
# 1            A-2 2016-02-08 06:07:59  Reynoldsburg    Franklin           OH
# 45631  A-2478861 2016-02-08 06:15:39    Cincinnati    Hamilton           OH
#
#       State     Zipcode       Street    Timezone  Temperature(F)  \
# 45629  Ohio       43017  Outerbelt E  US/Eastern            42.1
# 0      Ohio       45424       I-70 E  US/Eastern            36.9
# 45630  Ohio       45424       I-70 E  US/Eastern            36.9
# 1      Ohio  43068-3402     Brice Rd  US/Eastern            37.9
# 45631  Ohio       45203       I-75 S  US/Eastern            36.0
#
#        Visibility(mi) Weather_Condition
# 45629            10.0        Light Rain
# 0                10.0        Light Rain
# 45630            10.0        Light Rain
# 1                10.0        Light Rain
# 45631            10.0          Overcast

# %%
clean_accident_data_df_rename = clean_accident_data_df.copy()
clean_accident_data_df_rename = clean_accident_data_df_rename.rename(columns= {"ID": "id",
                                                                              "Date_Time": "datetime",
                                                                              "City": "city",
                                                                              "County": "county",
                                                                              "State": "state_name",
                                                                              "Zipcode": "zipcode",
                                                                              "Timezone": "timezone",
                                                                              "Temperature(F)": "temperature",
                                                                               "Visibility(mi)": "visibility",
                                                                               "Weather_Condition": "weather_condition"})
# drop street and state abbrev

# %%
clean_accident_data_df_rename.drop(columns= ["state_abbrev", "Street"], inplace=True)

# %%
clean_accident_data_df_rename.head()
# Out:
#               id            datetime          city      county state_name  \
# 45629  A-2478859 2016-02-08 00:37:08        Dublin    Franklin       Ohio
# 0            A-1 2016-02-08 05:46:00        Dayton  Montgomery       Ohio
# 45630  A-2478860 2016-02-08 05:56:20        Dayton  Montgomery       Ohio
# 1            A-2 2016-02-08 06:07:59  Reynoldsburg    Franklin       Ohio
# 45631  A-2478861 2016-02-08 06:15:39    Cincinnati    Hamilton       Ohio
#
#           zipcode    timezone  temperature  visibility weather_condition
# 45629       43017  US/Eastern         42.1        10.0        Light Rain
# 0           45424  US/Eastern         36.9        10.0        Light Rain
# 45630       45424  US/Eastern         36.9        10.0        Light Rain
# 1      43068-3402  US/Eastern         37.9        10.0        Light Rain
# 45631       45203  US/Eastern         36.0        10.0          Overcast

# %%
clean_accident_data_df_rename = clean_accident_data_df_rename.sort_values(by='datetime')
clean_accident_data_df_rename.head()
# Out:
#               id            datetime          city      county state_name  \
# 45629  A-2478859 2016-02-08 00:37:08        Dublin    Franklin       Ohio
# 0            A-1 2016-02-08 05:46:00        Dayton  Montgomery       Ohio
# 45630  A-2478860 2016-02-08 05:56:20        Dayton  Montgomery       Ohio
# 1            A-2 2016-02-08 06:07:59  Reynoldsburg    Franklin       Ohio
# 45631  A-2478861 2016-02-08 06:15:39    Cincinnati    Hamilton       Ohio
#
#           zipcode    timezone  temperature  visibility weather_condition
# 45629       43017  US/Eastern         42.1        10.0        Light Rain
# 0           45424  US/Eastern         36.9        10.0        Light Rain
# 45630       45424  US/Eastern         36.9        10.0        Light Rain
# 1      43068-3402  US/Eastern         37.9        10.0        Light Rain
# 45631       45203  US/Eastern         36.0        10.0          Overcast

# %%
clean_accident_data_df_rename = clean_accident_data_df_rename[['id', 'datetime', 'state_name', 'city', 'county', 'zipcode', 'timezone', 'temperature', 'visibility', 'weather_condition']]
clean_accident_data_df_rename.head()
# Out:
#               id            datetime state_name          city      county  \
# 45629  A-2478859 2016-02-08 00:37:08       Ohio        Dublin    Franklin
# 0            A-1 2016-02-08 05:46:00       Ohio        Dayton  Montgomery
# 45630  A-2478860 2016-02-08 05:56:20       Ohio        Dayton  Montgomery
# 1            A-2 2016-02-08 06:07:59       Ohio  Reynoldsburg    Franklin
# 45631  A-2478861 2016-02-08 06:15:39       Ohio    Cincinnati    Hamilton
#
#           zipcode    timezone  temperature  visibility weather_condition
# 45629       43017  US/Eastern         42.1        10.0        Light Rain
# 0           45424  US/Eastern         36.9        10.0        Light Rain
# 45630       45424  US/Eastern         36.9        10.0        Light Rain
# 1      43068-3402  US/Eastern         37.9        10.0        Light Rain
# 45631       45203  US/Eastern         36.0        10.0          Overcast

# %%
# clean_accident_data_df_rename.nunique()

# %% [markdown]
# ## Run Accident_Schema_Final.sql in Postgres now

# %%
# clean_accident_data_df_rename.to_csv("Resources/Output/accident.csv", index=False)

# %%
rds_connection_string =f'{username}:{password}@localhost:5432/us_accidents'

# %%
engine = create_engine(f'postgresql+psycopg2://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# H:\Anaconda\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "us_accidents" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-38-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2317         """
#    2318
# -> 2319         with self._optional_conn_ctx_manager(connection) as conn:
#    2320             return self.dialect.get_table_names(conn, schema)
#    2321
#
# H:\Anaconda\envs\PythonData\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2087     def _optional_conn_ctx_manager(self, connection=None):
#    2088         if connection is None:
# -> 2089             with self._contextual_connect() as conn:
#    2090                 yield conn
#    2091         else:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
# -> 2342                 Connection._handle_dbapi_exception_noconnection(
#    2343                     e, dialect, self
#    2344                 )
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1583         elif should_wrap:
# -> 1584             util.raise_(
#    1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# H:\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# H:\Anaconda\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "us_accidents" does not exist
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
clean_accident_data_df_rename.info()

# %%
clean_accident_data_df_rename.to_sql(name='accident', con=engine, if_exists='append', index=False)
